# %% [markdown]
# <a href="https://colab.research.google.com/github/GokulvasanV/pandas/blob/main/pandas_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Part-- 1**

# %%
print('hello world')
# Out:
# hello world

# %%
import pandas as pd

# %%
web_stats={'Day':[1,2,3,4,5,6],
           'Visitors':[65,34,87,23,39,92],
           'Bouncer_Rate':[65,73,62,64,54,56]}

# %%
df=pd.DataFrame(web_stats)
df
# Out:
#    Day  Visitors  Bouncer_Rate
# 0    1        65            65
# 1    2        34            73
# 2    3        87            62
# 3    4        23            64
# 4    5        39            54
# 5    6        92            56

# %%
# set index as "Day"
df.set_index('Day') # it won't replace in our dataframe
# Out:
#      Visitors  Bouncer_Rate
# Day
# 1          65            65
# 2          34            73
# 3          87            62
# 4          23            64
# 5          39            54
# 6          92            56

# %%
df
# Out:
#    Day  Visitors  Bouncer_Rate
# 0    1        65            65
# 1    2        34            73
# 2    3        87            62
# 3    4        23            64
# 4    5        39            54
# 5    6        92            56

# %%
# set index as "Day" and also replace in our dataframe
df.set_index('Day',inplace=True)
df
# Out:
#      Visitors  Bouncer_Rate
# Day
# 1          65            65
# 2          34            73
# 3          87            62
# 4          23            64
# 5          39            54
# 6          92            56

# %%
# show specific column
df['Visitors']
# Out:
# Day
# 1    65
# 2    34
# 3    87
# 4    23
# 5    39
# 6    92
# Name: Visitors, dtype: int64

# %%
# or you can use this code also for show specific column
df.Visitors
# Out:
# Day
# 1    65
# 2    34
# 3    87
# 4    23
# 5    39
# 6    92
# Name: Visitors, dtype: int64

# %% [markdown]
# in specific column code won't accept space between words(in column name)
#
# Ex:
#
# **df['Bouncer Rate'] # it will work properly**
#
# df.'Bouncer Rate' # here it won't work because this word has space

# %%
# show multiple columns 
print(df[['Bouncer_Rate','Visitors']])
# Out:
#      Bouncer_Rate  Visitors
# Day
# 1              65        65
# 2              73        34
# 3              62        87
# 4              64        23
# 5              54        39
# 6              56        92

# %%
# convert the dict into list
df.Visitors.tolist()
# Out:
# [65, 34, 87, 23, 39, 92]

# %% [markdown]
# print(df[['Bouncer_Rate','Visitors']]) # it won't work
#
# ***See Below***

# %%
import numpy as np

# %%
print(np.array(df[['Bouncer_Rate','Visitors']])) # convert these Dict columns into array
# Out:
# [[65 65]
#  [73 34]
#  [62 87]
#  [64 23]
#  [54 39]
#  [56 92]]

# %% [markdown]
# ## **Part-- 2**

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/data.csv")
print(df.head())
# Out:
#          Date  Duration  Pulse  Maxpulse  Calories
# 0  01/12/2022        60    110       130     409.1
# 1  02/12/2022        60    117       145     479.0
# 2  03/12/2022        60    103       135     340.0
# 3  04/12/2022        45    109       175     282.4
# 4  05/12/2022        45    117       148     406.0

# %%
df.set_index('Date',inplace=True)
print(df.head())
# Out:
#             Duration  Pulse  Maxpulse  Calories
# Date
# 01/12/2022        60    110       130     409.1
# 02/12/2022        60    117       145     479.0
# 03/12/2022        60    103       135     340.0
# 04/12/2022        45    109       175     282.4
# 05/12/2022        45    117       148     406.0

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset/newcsv2.csv') # create new csv data set

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset/newcsv2.csv',index_col=0) # it won't repeat index
df.head()
# Out:
#             Duration  Pulse  Maxpulse  Calories
# Date
# 01/12/2022        60    110       130     409.1
# 02/12/2022        60    117       145     479.0
# 03/12/2022        60    103       135     340.0
# 04/12/2022        45    109       175     282.4
# 05/12/2022        45    117       148     406.0

# %%
# rename the column
#df.columns=["no.of days"]
#df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset/newcsv3.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-96cd79875966> in <module>
#       1 # rename the column
# ----> 2 df.columns=["no.of days"]
#       3 df.head()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
# ...

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/dataset/newcsv4.csv', header=False) # it won't show column name

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/newcsv4.csv",names=['Date','Period','Pulse','Maxpulse','Calories'],index_col=0) #set the column name and won't show without index
df.head()
# Out:
#             Period  Pulse  Maxpulse  Calories
# Date
# 01/12/2022      60    110       130     409.1
# 02/12/2022      60    117       145     479.0
# 03/12/2022      60    103       135     340.0
# 04/12/2022      45    109       175     282.4
# 05/12/2022      45    117       148     406.0

# %%
df.to_html("/content/drive/MyDrive/Colab Notebooks/dataset/newcsv_html.html") # save for html file

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/dataset/newcsv4.csv",names=['Date','Period','Pulse','Maxpulse','Calories']) #set the column name and show with index
df.head()
# Out:
#          Date  Period  Pulse  Maxpulse  Calories
# 0  01/12/2022      60    110       130     409.1
# 1  02/12/2022      60    117       145     479.0
# 2  03/12/2022      60    103       135     340.0
# 3  04/12/2022      45    109       175     282.4
# 4  05/12/2022      45    117       148     406.0

# %%
# rename column name
df.rename(columns={'Period':'Duration'},inplace=True)
df.head()
# Out:
#          Date  Duration  Pulse  Maxpulse  Calories
# 0  01/12/2022        60    110       130     409.1
# 1  02/12/2022        60    117       145     479.0
# 2  03/12/2022        60    103       135     340.0
# 3  04/12/2022        45    109       175     282.4
# 4  05/12/2022        45    117       148     406.0

# %% [markdown]
# ## **part-- 3**

# %%
# import quandl
import pandas as pd

# %%
US_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')  # taking data from website
print(US_states)
# Out:
# [   Name &postal abbs. [1]                          Unnamed: 2_level_0  \
#    Name &postal abbs. [1] Name &postal abbs. [1].1 Unnamed: 2_level_1
# 0                 Alabama                      NaN                 AL
# 1                  Alaska                      NaN                 AK
# 2                 Arizona                      NaN                 AZ
# 3                Arkansas                      NaN                 AR
# 4              California                      NaN                 CA
# 5                Colorado                      NaN                 CO
# 6             Connecticut                      NaN                 CT
# 7                Delaware                      NaN                 DE
# 8                 Florida                      NaN                 FL
# 9                 Georgia                      NaN                 GA
# 10                 Hawaii                      NaN                 HI
# ...

# %%
US_states[0]
# Out:
#    Name &postal abbs. [1]                          Unnamed: 2_level_0  \
#    Name &postal abbs. [1] Name &postal abbs. [1].1 Unnamed: 2_level_1
# 0                 Alabama                      NaN                 AL
# 1                  Alaska                      NaN                 AK
# 2                 Arizona                      NaN                 AZ
# 3                Arkansas                      NaN                 AR
# 4              California                      NaN                 CA
# 5                Colorado                      NaN                 CO
# 6             Connecticut                      NaN                 CT
# 7                Delaware                      NaN                 DE
# 8                 Florida                      NaN                 FL
# 9                 Georgia                      NaN                 GA
# 10                 Hawaii                      NaN                 HI
# ...

# %% [markdown]
# ## ***part--4*** Concatenating and Appending dataframes

# %%
import pandas as pd

df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
concat = pd.concat([df1,df2]) #Concatenating df1 & df2
concat
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
concat = pd.concat([df1,df2,df3]) #Concatenating df1,df2,df3
concat
# Out:
#       HPI  Int_rate  US_GDP_Thousands  Low_tier_HPI
# 2001   80         2              50.0           NaN
# 2002   85         3              55.0           NaN
# 2003   88         2              65.0           NaN
# 2004   85         2              55.0           NaN
# 2005   80         2              50.0           NaN
# 2006   85         3              55.0           NaN
# 2007   88         2              65.0           NaN
# 2008   85         2              55.0           NaN
# 2001   80         2               NaN          50.0
# 2002   85         3               NaN          52.0
# 2003   88         2               NaN          50.0
# 2004   85         2               NaN          53.0

# %%
df4 = df1.append(df2) # appending df2 in df1
df4
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
df5 = df1.append(df3)
df5
# Out:
#       HPI  Int_rate  US_GDP_Thousands  Low_tier_HPI
# 2001   80         2              50.0           NaN
# 2002   85         3              55.0           NaN
# 2003   88         2              65.0           NaN
# 2004   85         2              55.0           NaN
# 2001   80         2               NaN          50.0
# 2002   85         3               NaN          52.0
# 2003   88         2               NaN          50.0
# 2004   85         2               NaN          53.0

# %%
# adding new row in our dataframe
ser = pd.Series([80,2,50], index=['HPI','Int_rate','US_GDP_Thousands'])
df6 = df1.append(ser, ignore_index=True)
df6
# Out:
#    HPI  Int_rate  US_GDP_Thousands
# 0   80         2                50
# 1   85         3                55
# 2   88         2                65
# 3   85         2                55
# 4   80         2                50
