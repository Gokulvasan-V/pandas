# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokulvasan-V/pandas/blob/main/Guvi_pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Beginner  Module**

# %% [markdown]
# ### Import CSV file

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Guvi_python/Guvi Premium courses/Pandas/Dataset/sales_information.csv')
df_copy = df.copy()

# %%
df.shape
# Out:
# (20, 6)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Sales Person', 'Date of Purchase', 'Total',
#        'Quantity'],
#       dtype='object')

# %%
df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity
# 0      India  North         John  12/19/2017 0:00:00  100000       567
# 1         US  North         Bill   6/25/2014 0:00:00  120000      3000
# 2         UK  North       Thomas   9/12/2010 0:00:00  140000       345
# 3  Australia   East         John   9/30/2011 0:00:00  160000      1000
# 4     Africa   East         Bill  11/20/2016 0:00:00  180000       123

# %%
df.tail()
# Out:
#       Country Region Sales Person    Date of Purchase   Total  Quantity
# 15         US   West         John   4/29/2015 0:00:00  220000        90
# 16         UK   West         Bill   4/15/2012 0:00:00  240000        90
# 17  Australia   West       Thomas  10/18/2016 0:00:00  260000        90
# 18     Africa  North         John   9/30/2012 0:00:00  140000        85
# 19  Singapore  North         Bill    1/7/2013 0:00:00  150000        85

# %%
df.describe()
# Out:
#               Total     Quantity
# count  2.000000e+01    20.000000
# mean   1.502500e+06   977.900000
# std    5.769280e+06  1761.923497
# min    1.000000e+05    85.000000
# 25%    1.400000e+05    90.000000
# 50%    1.700000e+05   505.500000
# 75%    2.250000e+05  1000.000000
# max    2.600000e+07  7890.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           20 non-null     object
#  1   Region            20 non-null     object
#  2   Sales Person      20 non-null     object
#  3   Date of Purchase  20 non-null     object
#  4   Total             20 non-null     int64
#  5   Quantity          20 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# #### Filer Columns

# %%
print(df['Country'] )
# Out:
# 0         India
# 1            US
# 2            UK
# 3     Australia
# 4        Africa
# 5     Singapore
# 6       Mylasia
# 7         India
# 8            US
# 9            UK
# 10    Australia
# 11       Africa
# 12    Singapore
# 13      Mylasia
# 14        India
# 15           US
# 16           UK
# 17    Australia
# 18       Africa
# 19    Singapore
# Name: Country, dtype: object

# %%
print(type(df['Country']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# df['Country', 'Region'] # It will show error because that is 3-D

df[['Country', 'Region']]
# Out:
#       Country Region
# 0       India  North
# 1          US  North
# 2          UK  North
# 3   Australia   East
# 4      Africa   East
# 5   Singapore   East
# 6     Mylasia   West
# 7       India   West
# 8          US   West
# 9          UK  North
# 10  Australia  North
# 11     Africa  North
# 12  Singapore   East
# 13    Mylasia   East
# 14      India   East
# 15         US   West
# 16         UK   West
# 17  Australia   West
# 18     Africa  North
# 19  Singapore  North

# %%
print(type(df[['Country', 'Region']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df[['Country']]
# Out:
#       Country
# 0       India
# 1          US
# 2          UK
# 3   Australia
# 4      Africa
# 5   Singapore
# 6     Mylasia
# 7       India
# 8          US
# 9          UK
# 10  Australia
# 11     Africa
# 12  Singapore
# 13    Mylasia
# 14      India
# 15         US
# 16         UK
# 17  Australia
# 18     Africa
# 19  Singapore

# %%
print(type(df[['Country']]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# #### Filter Rows

# %%
df.iloc[0:3]
# Out:
#   Country Region Sales Person    Date of Purchase   Total  Quantity
# 0   India  North         John  12/19/2017 0:00:00  100000       567
# 1      US  North         Bill   6/25/2014 0:00:00  120000      3000
# 2      UK  North       Thomas   9/12/2010 0:00:00  140000       345

# %%
df[['Country','Region']].iloc[0:3]
# Out:
#   Country Region
# 0   India  North
# 1      US  North
# 2      UK  North

# %% [markdown]
# **Filter rows based on some specific value**

# %%
# df[df['Country'] == 'India' & df['Total'] >= 200000] # it will show error

df[(df['Country'] == 'India') & (df['Total'] >= 200000)]
# Out:
#    Country Region Sales Person   Date of Purchase   Total  Quantity
# 7    India   West         Bill   4/8/2014 0:00:00  240000       200
# 14   India   East       Thomas  11/9/2010 0:00:00  200000        90

# %%
df
# Out:
#       Country Region Sales Person    Date of Purchase     Total  Quantity
# 0       India  North         John  12/19/2017 0:00:00    100000       567
# 1          US  North         Bill   6/25/2014 0:00:00    120000      3000
# 2          UK  North       Thomas   9/12/2010 0:00:00    140000       345
# 3   Australia   East         John   9/30/2011 0:00:00    160000      1000
# 4      Africa   East         Bill  11/20/2016 0:00:00    180000       123
# 5   Singapore   East       Thomas   8/17/2016 0:00:00    200000      1000
# 6     Mylasia   West         John   9/15/2014 0:00:00   1000000      7890
# 7       India   West         Bill    4/8/2014 0:00:00    240000       200
# 8          US   West       Thomas  11/25/2016 0:00:00  26000000      1000
# 9          UK  North         John  12/15/2012 0:00:00    100000      1000
# 10  Australia  North         Bill    9/6/2011 0:00:00    120000       567
# 11     Africa  North       Thomas   12/8/2017 0:00:00    140000      1000
# ...

# %% [markdown]
# How to add New Colums and Rows in Existing DataFrame (or) Dataset

# %%
# adding new column

calls_made = [10,60] *10
calls_made
# Out:
# [10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60,
#  10,
#  60]

# %%
df['Calls_made'] = calls_made
df.head()
# Out:
#      Country Region Sales Person    Date of Purchase   Total  Quantity  \
# 0      India  North         John  12/19/2017 0:00:00  100000       567
# 1         US  North         Bill   6/25/2014 0:00:00  120000      3000
# 2         UK  North       Thomas   9/12/2010 0:00:00  140000       345
# 3  Australia   East         John   9/30/2011 0:00:00  160000      1000
# 4     Africa   East         Bill  11/20/2016 0:00:00  180000       123
#
#    Calls_made
# 0          10
# 1          60
# 2          10
# 3          60
# 4          10

# %%
type(df['Date of Purchase'][0])
# Out:
# str

# %%
# Adding New Row

new_row = [['china', 'East', 'Jim', '12/19/2017 0:00:00', 70000, 700, 40 ]] # Because this is 2D array, that's why we are adding dual list

new_df_row = pd.DataFrame(new_row, columns = df.columns.values)
df.append(new_df_row,
          ignore_index = True) # ignore index --> for continuity index value, Otherwise index will start from 0
# Out:
# <ipython-input-22-a5fbf4afc6c1>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_df_row,
#       Country Region Sales Person    Date of Purchase     Total  Quantity  \
# 0       India  North         John  12/19/2017 0:00:00    100000       567
# 1          US  North         Bill   6/25/2014 0:00:00    120000      3000
# 2          UK  North       Thomas   9/12/2010 0:00:00    140000       345
# 3   Australia   East         John   9/30/2011 0:00:00    160000      1000
# 4      Africa   East         Bill  11/20/2016 0:00:00    180000       123
# 5   Singapore   East       Thomas   8/17/2016 0:00:00    200000      1000
# 6     Mylasia   West         John   9/15/2014 0:00:00   1000000      7890
# 7       India   West         Bill    4/8/2014 0:00:00    240000       200
# 8          US   West       Thomas  11/25/2016 0:00:00  26000000      1000
# ...

# %% [markdown]
# ## **Intermediate Module**

# %% [markdown]
# **Sorting the DataFrame**
#
# here i am going to modify some changes

# %%
po_number = [int(f'1000{i}') for i in range(20)]
po_number
# Out:
# [10000,
#  10001,
#  10002,
#  10003,
#  10004,
#  10005,
#  10006,
#  10007,
#  10008,
#  10009,
#  100010,
#  100011,
#  100012,
#  100013,
#  100014,
#  100015,
#  100016,
#  100017,
#  100018,
#  100019]

# %%
import random
random.shuffle(po_number)
po_number
# Out:
# [10002,
#  100012,
#  10001,
#  100010,
#  100019,
#  100018,
#  100013,
#  10009,
#  10005,
#  10003,
#  10008,
#  100017,
#  10004,
#  100014,
#  10000,
#  10007,
#  100016,
#  10006,
#  100011,
#  100015]

# %%
df['po_number'] = po_number
df.set_index('po_number', inplace = True)
df.head()
# Out:
#              Country Region Sales Person    Date of Purchase   Total  \
# po_number
# 10002          India  North         John  12/19/2017 0:00:00  100000
# 100012            US  North         Bill   6/25/2014 0:00:00  120000
# 10001             UK  North       Thomas   9/12/2010 0:00:00  140000
# 100010     Australia   East         John   9/30/2011 0:00:00  160000
# 100019        Africa   East         Bill  11/20/2016 0:00:00  180000
#
#            Quantity  Calls_made
# po_number
# 10002           567          10
# 100012         3000          60
# 10001           345          10
# 100010         1000          60
# 100019          123          10

# %% [markdown]
# Sorting index column

# %%
df.sort_index(inplace = True)
df.head()
# Out:
#              Country Region Sales Person    Date of Purchase   Total  \
# po_number
# 10000          India   East       Thomas   11/9/2010 0:00:00  200000
# 10001             UK  North       Thomas   9/12/2010 0:00:00  140000
# 10002          India  North         John  12/19/2017 0:00:00  100000
# 10003             UK  North         John  12/15/2012 0:00:00  100000
# 10004      Singapore   East         John   7/30/2014 0:00:00  160000
#
#            Quantity  Calls_made
# po_number
# 10000            90          10
# 10001           345          10
# 10002           567          10
# 10003          1000          60
# 10004           892          10

# %%
df.sort_index(ascending = False) # ascending = False ---> Descending order
# Out:
#              Country Region Sales Person    Date of Purchase     Total  \
# po_number
# 100019        Africa   East         Bill  11/20/2016 0:00:00    180000
# 100018     Singapore   East       Thomas   8/17/2016 0:00:00    200000
# 100017        Africa  North       Thomas   12/8/2017 0:00:00    140000
# 100016            UK   West         Bill   4/15/2012 0:00:00    240000
# 100015     Singapore  North         Bill    1/7/2013 0:00:00    150000
# 100014       Mylasia   East         Bill   10/8/2016 0:00:00    180000
# 100013       Mylasia   West         John   9/15/2014 0:00:00   1000000
# 100012            US  North         Bill   6/25/2014 0:00:00    120000
# 100011        Africa  North         John   9/30/2012 0:00:00    140000
# 100010     Australia   East         John   9/30/2011 0:00:00    160000
# 10009          India   West         Bill    4/8/2014 0:00:00    240000
# 10008      Australia  North         Bill    9/6/2011 0:00:00    120000
# ...

# %% [markdown]
# Sorting values column

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Sales Person', 'Date of Purchase', 'Total',
#        'Quantity', 'Calls_made'],
#       dtype='object')

# %%
df.sort_values('Country',inplace = True)
df.head(10)
# Out:
#              Country Region Sales Person    Date of Purchase    Total  \
# po_number
# 100019        Africa   East         Bill  11/20/2016 0:00:00   180000
# 100017        Africa  North       Thomas   12/8/2017 0:00:00   140000
# 100011        Africa  North         John   9/30/2012 0:00:00   140000
# 100010     Australia   East         John   9/30/2011 0:00:00   160000
# 10008      Australia  North         Bill    9/6/2011 0:00:00   120000
# 10006      Australia   West       Thomas  10/18/2016 0:00:00   260000
# 10000          India   East       Thomas   11/9/2010 0:00:00   200000
# 10002          India  North         John  12/19/2017 0:00:00   100000
# 10009          India   West         Bill    4/8/2014 0:00:00   240000
# 100013       Mylasia   West         John   9/15/2014 0:00:00  1000000
#
#            Quantity  Calls_made
# po_number
# 100019          123          10
# 100017         1000          60
# 100011           85          10
# 100010         1000          60
# ...

# %%
df.sort_values(['Country', 'Region'],inplace = True)
df.head(10)
# Out:
#              Country Region Sales Person    Date of Purchase   Total  \
# po_number
# 100019        Africa   East         Bill  11/20/2016 0:00:00  180000
# 100017        Africa  North       Thomas   12/8/2017 0:00:00  140000
# 100011        Africa  North         John   9/30/2012 0:00:00  140000
# 100010     Australia   East         John   9/30/2011 0:00:00  160000
# 10008      Australia  North         Bill    9/6/2011 0:00:00  120000
# 10006      Australia   West       Thomas  10/18/2016 0:00:00  260000
# 10000          India   East       Thomas   11/9/2010 0:00:00  200000
# 10002          India  North         John  12/19/2017 0:00:00  100000
# 10009          India   West         Bill    4/8/2014 0:00:00  240000
# 100014       Mylasia   East         Bill   10/8/2016 0:00:00  180000
#
#            Quantity  Calls_made
# po_number
# 100019          123          10
# 100017         1000          60
# 100011           85          10
# 100010         1000          60
# ...

# %%
df.sort_values(['Country', 'Region'], ascending= False)
# Out:
#              Country Region Sales Person    Date of Purchase     Total  \
# po_number
# 10007             US   West         John   4/29/2015 0:00:00    220000
# 10005             US   West       Thomas  11/25/2016 0:00:00  26000000
# 100012            US  North         Bill   6/25/2014 0:00:00    120000
# 100016            UK   West         Bill   4/15/2012 0:00:00    240000
# 10003             UK  North         John  12/15/2012 0:00:00    100000
# 10001             UK  North       Thomas   9/12/2010 0:00:00    140000
# 100015     Singapore  North         Bill    1/7/2013 0:00:00    150000
# 10004      Singapore   East         John   7/30/2014 0:00:00    160000
# 100018     Singapore   East       Thomas   8/17/2016 0:00:00    200000
# 100013       Mylasia   West         John   9/15/2014 0:00:00   1000000
# 100014       Mylasia   East         Bill   10/8/2016 0:00:00    180000
# 10009          India   West         Bill    4/8/2014 0:00:00    240000
# ...

# %% [markdown]
# **Handling Datetime fields in Pandas**

# %%
# df['Date of Purchase']
df['Date of Purchase'].iloc[0]
# Out:
# '11/20/2016 0:00:00'

# %%
type(df['Date of Purchase'].iloc[0])
# Out:
# str

# %%
# concerting str to Timestamp type
df['Date of Purchase'] = pd.to_datetime(df['Date of Purchase'])

# %%
type(df['Date of Purchase'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# Need to extract the date, Month, year, time (Hours, Minutes, Seconds)

# %%
df['Year'] = df['Date of Purchase'].dt.year

# %%
df
# Out:
#              Country Region Sales Person Date of Purchase     Total  Quantity  \
# po_number
# 100019        Africa   East         Bill       2016-11-20    180000       123
# 100017        Africa  North       Thomas       2017-12-08    140000      1000
# 100011        Africa  North         John       2012-09-30    140000        85
# 100010     Australia   East         John       2011-09-30    160000      1000
# 10008      Australia  North         Bill       2011-09-06    120000       567
# 10006      Australia   West       Thomas       2016-10-18    260000        90
# 10000          India   East       Thomas       2010-11-09    200000        90
# 10002          India  North         John       2017-12-19    100000       567
# 10009          India   West         Bill       2014-04-08    240000       200
# 100014       Mylasia   East         Bill       2016-10-08    180000       444
# 100013       Mylasia   West         John       2014-09-15   1000000      7890
# ...
